# %% [markdown]
# <a href="https://colab.research.google.com/github/nov05/Google-Colaboratory/blob/master/20250602_tokenization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# * Notebook modified by nov05 on 2025-06-02

# %%
# %%time
import transformers
print(transformers.__version__)
# Out:
# 4.52.2
# CPU times: user 1.23 ms, sys: 168 µs, total: 1.4 ms
# Wall time: 8.16 ms

# %% [markdown]
# Expected output
# ```
# [CLS] the quick brown fox jumps over the lazy dog! [SEP]
# [101, 1996, 4248, 2829, 4419, 14523, 2058, 1996, 13971, 3899, 999, 102]
# [CLS], the, quick, brown, fox, jumps, over, the, lazy, dog, !, [SEP]
# ```

# %%
from transformers import AutoTokenizer

# Load a pre-trained tokenizer
model_name = "meta-llama/Meta-Llama-3-8B"  # deepseek-ai/DeepSeek-V2"
tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")

# Tokenize a text
text = "The quick brown fox jumps over the lazy dog!"
encoded_text = tokenizer(text)

# Access the tokenized IDs
print(tokenizer.decode(encoded_text["input_ids"]))
print(encoded_text["input_ids"])
print(", ".join([tokenizer.decode(t) for t in encoded_text["input_ids"]]))
# Out:
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# [CLS] the quick brown fox jumps over the lazy dog! [SEP]
# [101, 1996, 4248, 2829, 4419, 14523, 2058, 1996, 13971, 3899, 999, 102]
# [CLS], the, quick, brown, fox, jumps, over, the, lazy, dog, !, [SEP]
